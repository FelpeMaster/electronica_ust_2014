# %% [markdown]
# # Filtros.

# %%
from IPython.core.display import HTML 
HTML('<img src="funciones.jpg" width=500 height=100/>')
# Out:
# <img src="funciones.jpg" width=500 height=100/>

# %% [markdown]
# ## Idea intuitiva

# %% [markdown]
# Una forma de razonar es decir que un filtro es un elemento que permite el paso de determinados elementos que tienen ciertas propiedades y no permitirles el paso a traves de él a otros que carecen de dichas propiedades.

# %%
from IPython.core.display import HTML 
HTML('<img src="S2. Balde de Encaje.jpg" width=500 height=100/>')
# Out:
# <img src="S2. Balde de Encaje.jpg" width=500 height=100/>

# %%
from IPython.core.display import HTML 
HTML('<img src="filtro1.svg" width=500 height=100/>')
# Out:
# <img src="filtro1.svg" width=500 height=100/>

# %% [markdown]
# En temas de tratamiento de señal (disciplina electrónica y de cs de la computación) el patron que se busca es la frecuencia ($f$) o frecuencia angular ($\omega$)

# %%
# %pylab inline
import numpy as np
import pylab as pl
w1 = 2*np.pi*0.001
w2 = 2*np.pi*0.01
w3 = 2*np.pi*0.1
w4 = 2*np.pi*1
w5 = 2*np.pi*10
t = np.arange(0,2000,0.001)
pl.figure(figsize=(10, 20), dpi=1000)
v1 = np.sin(w1*t)
v2 = np.sin(w2*t)
v3 = np.sin(w3*t)
v4 = np.sin(w4*t)
v5 = np.sin(w5*t)
pl.subplot(5,1,1)
pl.plot(t,v1)
pl.title('$\omega = 2  \pi  (0,001)$', fontsize = 16)
#pl.legend(r'$v(t) = \sin{(2  \pi  (0,001)}$')
pl.subplot(5,1,2)
pl.title('$\omega = 2 \pi (0,01)$', fontsize = 16)
pl.xlim([0,400])
pl.plot(t,v2)
pl.subplot(5,1,3)
pl.title('$\omega = 2 \pi (0,1)$', fontsize = 16)
pl.xlim([0,40])
pl.plot(t,v3)
pl.subplot(5,1,4)
pl.xlim([0,4])
pl.title('$\omega = 2 \pi (1,0)$', fontsize = 16)
pl.plot(t,v4)
pl.subplot(5,1,5)
pl.xlim([0,0.4])
pl.title('$\omega = 2 \pi (10,0)$', fontsize = 16)
pl.plot(t,v5)
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML 
HTML('<img src="espectro-electromagnetico.png" width=900 height=300/>')
# Out:
# <img src="espectro-electromagnetico.png" width=900 height=300/>

# %% [markdown]
# Recordar la ecuación de onda \begin{equation} v = \lambda f \end{equation}

# %% [markdown]
# Existe una relación entre señales sinusoidales y el espectro de frecuencia.

# %%
#-*- coding: utf-8 -*-
# %pylab inline
from scipy.fftpack import fft
import numpy as np
import pylab as pl
# Number of samplepoints
N = 6000
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = 5*np.sin(20.0 * 2.0*np.pi*x)# + 0.5*np.sin(80.0 * 2.0*np.pi*x)
y2 = 10*np.sin(15.0 * 2.0*np.pi*x)# + 0.5*np.sin(80.0 * 2.0*np.pi*x)
y = y + y2
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
pl.figure(figsize=(16, 6), dpi=1000)
pl.subplot(1,2,1)
pl.plot(x, y)
pl.xlim(0.1,0.3)
pl.title('dominio temporal')
pl.grid()
pl.subplot(1,2,2)
pl.xlim(10,30)
pl.title('dominio frecuencial Aplicando FFT a la senal de entrada')
pl.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
pl.grid()
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# Una forma de hacer filtros es trabajando con circuitos eléctricos con elementos pasivos como condensadores, bobinas y resistencias. Para ello recordaremos sus expresiones más comunes.

# %% [markdown]
# \begin{eqnarray}
# v_C = \frac{1}{C}\int_{0}^t i_C dt + v_{C0}\\
# i_C = \frac{dv_C}{dt}\\
# v_L =\frac{di_L}{dt}\\
# i_L = \frac{1}{L}\int_{0}^t v_L dt + i_{L0}\\
# v_R = iR\\
# i_R = \frac{v}{R}
# \end{eqnarray}

# %% [markdown]
# Al momento de armar circuitos eléctricos complejos hace dificilmente manejable establecer las ecuaciones. Motivo por el cual se recurre a hacer un cambio. Se introdice la impedancia, este es un parámetro electrico semejante a la resistencia electrica con la diferencia de que se trabaja en el domino de la frecuencia con numeros complejos.

# %%
from IPython.core.display import HTML 
HTML('<img src="impedanciaC.svg" width=500 height=100/>')
# Out:
# <img src="impedanciaC.svg" width=500 height=100/>

# %% [markdown]
# con \begin{eqnarray}
# Z_C = \frac{1}{j\omega C} = \frac{1}{j2 \pi f  C}\\
# \omega  = 2 \pi f, \ y \ j = \sqrt{-1}
# \end{eqnarray}

# %% [markdown]
# En general al parametro Z se le llama impedancia, esta depende de la frecuencia de la señal. Al trabajar con impedancias se puede trabajar de forma simular a los circuitos resistivos. De ese modo se configurarán los filtros. Nota: debe considerar que la expresión $j^2 = -1,$  pues $j = \sqrt{-1} $

# %% [markdown]
# Recordar que $\omega  = 2 \pi f$. A continuación se presentan diferentes casos de frecuencia angular.

# %%
# %pylab inline
import numpy as np
import pylab as pl
pl.figure(figsize=(6, 6), dpi=1000)
frame1 = pl.gca()
ax = pl.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0.))
pl.plot(np.array([0,3]), np.array([0,5]),'')
pl.scatter([3, ],[5, ], 50, color='red')
pl.annotate(r'$Z = a + jb$',
            xy=(3, 5), xycoords='data',
            xytext=(+50, +20), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))
#pl.plot(3, 5, 'o')
pl.plot(np.array([0,3]), np.array([5,5]),'--',color='red')
pl.plot(np.array([3,3]), np.array([0,5]),'--',color='red')
x_values = ["", "", "", "a","",""]
y_values = ["", "", "", "", "", "b", ""]
x_axis = np.arange(0, 5, 1)
y_axis = np.arange(0, 7, 1)
pl.yticks(y_axis, y_values, fontsize = 20)
pl.xticks(x_axis, x_values, fontsize = 20)
pl.xlabel('Eje Real', fontsize = 20)
pl.ylabel('Eje Imaginario', fontsize = 20)
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Determine el voltaje en el condensador.

# %%
from IPython.core.display import HTML
HTML('<img src="filtrorc1.svg" width=500 height=100/>')
# Out:
# <img src="filtrorc1.svg" width=500 height=100/>

# %% [markdown]
# ## Solución.

# %% [markdown]
# si reemplazamos al condensador por la impedancia se tiene que $Z_C = \frac{1}{j \omega C}$ y $Z_R = R$ y aplicando la Ley de LKV. Se puede obtener lo siguiente:
# \begin{eqnarray}
# - V_{in} + Z_R I+ Z_C I = 0\\
# I = \frac{V_{in}}{Z_R + Z_C} \\
# I = \frac{V_{in}}{R + \frac{1}{j \omega C}} \\
# V_0(\omega) = I Z_C \\
# V_0(\omega) = \frac{V_{in}}{R + \frac{1}{j \omega C}} \frac{1}{j \omega C} \\
# V_0(\omega) = \frac{j \omega CV_{in}}{Rj \omega C + 1} \frac{1}{j \omega C}\\
# V_0(\omega) = \frac{j \omega CV_{in}}{R(j \omega C)^2 + j \omega C}\\
# V_0(\omega) = \frac{j \omega CV_{in}}{j \omega C - R(\omega C)^2}\\
# V_0(\omega) = \frac{j V_{in}}{j - R\omega C}
# \end{eqnarray}

# %% [markdown]
# si reemplazamos al condensador por la impedancia se tiene que $Z_C = \frac{1}{j \omega C}$ y $Z_R = R$ y aplicando la Ley de LKV. Se puede obtener lo siguiente:
# si hacemos un cambio de variable $\mathcal{S} = j\omega $
# \begin{eqnarray}
# - V_{in} + Z_R I+ Z_C I = 0\\
# I = \frac{V_{in}}{Z_R + Z_C} \\
# I = \frac{V_{in}}{R + \frac{1}{j \omega C}} \\
# V_0(\omega) = I Z_C \\
# V_0(\omega) = \frac{V_{in}}{R + \frac{1}{j \omega C}} \frac{1}{j \omega C} \\
# V_0(\omega) = \frac{V_{in}}{R + \frac{1}{\mathcal{S} C}} \frac{1}{\mathcal{S} C} \\
# V_0(\omega) = \frac{V_{in}}{\mathcal{S} RC + 1} \\
# V_0(\omega) = \frac{V_{in}}{j \omega RC + 1}
# \end{eqnarray}

# %% [markdown]
# La ultima expresión se puede trabajar un poco más, por lo general se trabaja en terminos de numero complejo con. Un $Z$ se representa como $Z = a + jb$, con $a,b\in \mathbb{R}$ y $j = \sqrt{-1}$. Si se hace un arreglo algebraico en la ultima expresión tendremos lo siguiente.

# %% [markdown]
# \begin{eqnarray}
# V_0(\omega) = \frac{-j V_{in}}{ R\omega C - j} \frac{R\omega C + j}{R\omega C + j} \\
# V_0(\omega) = \frac{V_{in}-j V_{in}R\omega C}{ (R\omega C)^2 + 1}\\
# V_0(\omega) = \frac{V_{in}}{ (R\omega C)^2 + 1} -j \frac{ V_{in}R\omega C}{ (R\omega C)^2 + 1}
# \end{eqnarray}

# %% [markdown]
# Definimos la función de transferencia $H(\omega) = \frac{v_{0}(\omega)}{v_{in}(\omega)}$ y de esa forma para el ejemplo se tendrá.
# \begin{eqnarray}
# \frac{V_0(\omega)}{V_{in}(\omega)} = \frac{\frac{V_{in}}{ (R\omega C)^2 + 1} -j \frac{ V_{in}R\omega C}{ (R\omega C)^2 + 1}}{V_{in}}\\
# H(\omega) = \frac{1}{ (R\omega C)^2 + 1} -j \frac{R\omega C}{ (R\omega C)^2 + 1}
# \end{eqnarray}

# %%
# %pylab inline
import numpy as np
import pylab as pl
C = 100e-6
R = 1e2

w = np.arange(0.0001,4/(R*C),0.0001)
wang = np.arange(0.0001,50,0.0001)
aang = 1/((R*C*wang)**2+1)
bang = R*C*wang/((R*C*wang)**2+1)

a = 1/((R*C*w)**2+1)
b = R*C*w/((R*C*w)**2+1)

w1 = 0.1
a1 = 1/((R*C*w1)**2+1)
b1 = R*C*w1/((R*C*w1)**2+1)

w2 = 1
a2 = 1/((R*C*w2)**2+1)
b2 = R*C*w2/((R*C*w2)**2+1)

w3 = 10
a3 = 1/((R*C*w3)**2+1)
b3 = R*C*w3/((R*C*w3)**2+1)

w4 = 100
a4 = 1/((R*C*w4)**2+1)
b4 = R*C*w4/((R*C*w4)**2+1)

w5 = 200
a5 = 1/((R*C*w5)**2+1)
b5 = R*C*w5/((R*C*w5)**2+1)

w6 = 400
a6 = 1/((R*C*w6)**2+1)
b6 = R*C*w6/((R*C*w6)**2+1)

w7 = 50
a7 = 1/((R*C*w7)**2+1)
b7 = R*C*w7/((R*C*w7)**2+1)

pl.figure(figsize=(16, 10), dpi=1000)
pl.annotate('$\omega = 0.1$',
            xy=(a1, b1), xycoords='data',
            xytext=(-150, +50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate('$\omega = 1$',
            xy=(a2, b2), xycoords='data',
            xytext=(-50, +50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate('$\omega = 10$',
            xy=(a3, b3), xycoords='data',
            xytext=(-100, +50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate('$\omega = 100$',
            xy=(a4, b4), xycoords='data',
            xytext=(-0, -50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate('$\omega = 200$',
            xy=(a5, b5), xycoords='data',
            xytext=(-0, -50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate('$\omega = 400$',
            xy=(a6, b6), xycoords='data',
            xytext=(-50, +50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate('$\omega = 50$',
            xy=(a7, b7), xycoords='data',
            xytext=(-50, -50), textcoords='offset points', fontsize=20,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.annotate(r'$\angle{H(\omega = 50)} = \phi$',
            xy=(0.3, 0.09), xycoords='data',
            xytext=(-50, -30), textcoords='offset points', fontsize=40,)



pl.plot(a,b,'--',color = 'blue')
pl.plot(0.25*aang,0.25*bang,'--',color = 'red')
pl.plot(np.array([0,a1]),np.array([0,b1]),color = 'black')
pl.plot(np.array([0,a2]),np.array([0,b2]),color = 'black')
pl.plot(np.array([0,a3]),np.array([0,b3]),color = 'black')
pl.plot(np.array([0,a4]),np.array([0,b4]),color = 'black')
pl.plot(np.array([0,a5]),np.array([0,b5]),color = 'black')
pl.plot(np.array([0,a6]),np.array([0,b6]),color = 'black')
pl.plot(np.array([0,a7]),np.array([0,b7]),color = 'red')
titulo = 'Funcion de Transferencia $H(\omega)}$'
pl.title( titulo,fontsize = 20)
#pl.title( r'$H(\omega) = \frac{1}{ (R\omega C)^2 + 1} -j \frac{R\omega C}{ (R\omega C)^2 + 1}$',fontsize = 20)
pl.xlabel('Eje Real', fontsize = 20)
pl.ylabel('Eje Imaginario', fontsize = 20)
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Magnitud y Fase.

# %% [markdown]
# Si representamos un numero complejo de valor $Z = a + bj$ en el plano complejo tenemos lo siguiente.

# %% [markdown]
# Se define la magnitud se determina como:
#     \begin{equation}
#     \lvert H(\omega)\rvert\ = \sqrt{a^2 + b^2}
#     \end{equation}

# %% [markdown]
# La fase se define como:
#     \begin{equation}
#     \phi(\omega) = \angle{H(\omega)} = \tan^{-1}{\left(\frac{b}{a}\right)}
#     \end{equation}

# %% [markdown]
# Dependiendo de la literatura consultada pueden encontrar que la fase de una función de transferencia se puede denotar como $\phi$ ó $\angle{H(\omega)}$

# %% [markdown]
# Para el caso del ejemplo
# \begin{eqnarray}
# H(\omega) = \frac{1}{ (R\omega C)^2 + 1} -j \frac{R\omega C}{ (R\omega C)^2 + 1}\\
# a = \frac{1}{ (R\omega C)^2 + 1}\\
# b = -\frac{R\omega C}{ (R\omega C)^2 + 1}\\
# \lvert H(\omega)\rvert\ = \sqrt{\left(\frac{1}{ (R\omega C)^2 + 1}\right)^2 + \left(-\frac{R\omega C}{ (R\omega C)^2 + 1}\right)^2} \\
# \lvert H(\omega)\rvert\ = \sqrt{\left(\frac{1}{ (R\omega C)^2 + 1}\right)^2 \left[1 + \left(R \omega C\right)^2\right]} \\
# \lvert H(\omega)\rvert\ = \left(\frac{1}{ (R\omega C)^2 + 1}\right)\sqrt{ 1 + \left(R \omega C\right)^2}
# \end{eqnarray}
# De lo cual se puede obtener la siguiente gráfica si $C = 100\mu F$, $R = 100\Omega$

# %%
# %pylab inline
import numpy as np
import pylab as pl
C = 100e-6
R = 1e2
w = np.arange(0.0001,4/(R*C),0.0001)
absH = (1/(1 + (R*w*C)**2))*(1 + (R*C*w)**2)**0.5
wres = 1/(R*C)
anotacion = np.array([wres, (1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5])
anotacion2 = np.array([wres, 20*np.log10((1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5)])

pl.figure(figsize=(16, 10), dpi=500)
pl.subplot(2,1,1)
pl.plot(np.array([0,wres]),np.array([(1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5,(1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5]),'--',color='red')
pl.plot(np.array([wres,wres]),np.array([0,(1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5]),'--',color='red')
pl.plot(w,absH)
pl.grid()
pl.annotate(anotacion,
            xy=(wres, (1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5), xycoords='data',
            xytext=(+50, +20), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))

pl.xlabel('$\omega [rad/s]$', fontsize = 20)
pl.ylabel('$ |H(\omega)| $', fontsize = 20)
pl.subplot(2,1,2)
pl.xlabel('$\omega [rad/s]$', fontsize = 20)
pl.ylabel('$20\log{| H(\omega)|}$', fontsize = 20)
marca1 = 20*np.log10((1/(1 + (R*wres*C)**2))*(1 + (R*C*wres)**2)**0.5)
pl.plot(np.array([0,wres]),np.array([marca1,marca1]),'--',color='red')
pl.plot(np.array([wres,wres]),np.array([0,marca1]),'--',color='red')
pl.plot(w,20*np.log10(absH))
pl.annotate(anotacion2,
            xy=(wres, marca1), xycoords='data',
            xytext=(+50, +20), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.35"))
pl.grid()
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Por otro lado se tiene la fase

# %% [markdown]
# Para el caso del ejemplo
# \begin{eqnarray}
# H(\omega) = \frac{1}{ (R\omega C)^2 + 1} -j \frac{R\omega C}{ (R\omega C)^2 + 1}\\
# a = \frac{1}{ (R\omega C)^2 + 1}\\
# b = -\frac{R\omega C}{ (R\omega C)^2 + 1}\\
# \angle{H} = \tan^{-1}\left(\frac{-\frac{R\omega C}{ (R\omega C)^2 + 1}}{\frac{1}{ (R\omega C)^2 + 1}} \right)\\
# \angle{H} = \tan^{-1}\left( -R\omega C \right)
# \end{eqnarray}
# De lo cual se puede obtener la siguiente gráfica si $C = 100\mu F$, $R = 100\Omega$

# %%
# %pylab inline
import numpy as np
import pylab as pl
C = 100e-6
R = 1e2
w = np.arange(0.0001,4/(R*C),0.0001)
angulo = np.arctan(-R*w*C)
pl.figure(figsize=(16, 10), dpi=1000)
pl.xlabel('$\omega [rad/s]$', fontsize = 20)
pl.ylabel('$H$', fontsize = 20)
pl.plot(w,angulo)
pl.plot(np.array([0,4/(R*C)]),np.array([-np.pi/2 , -np.pi/2]),'--')
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Para más información.

# %%
from IPython.display import IFrame
IFrame('http://www.dte.us.es/ing_inf/ins_elec/temario/Tema%204.%20Filtros.pdf', width=1024, height=600)
# Out:
#         <iframe
#             width="1024"
#             height=600"
#             src="http://www.dte.us.es/ing_inf/ins_elec/temario/Tema%204.%20Filtros.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# \begin{equation}
# H = \frac{j\omega CR +(\omega CR )^2 }{1 + (\omega CR )^2}
# \end{equation}

# %%
# %pylab inline
import numpy as np
import pylab as pl
C = 100e-6
R = 1e2
w = np.arange(0,4/(R*C), 0.001)
de = 1 +  (w*R*C)**2
MH = np.sqrt(((w*C*R)/de)**2 + ((w*C*R)**2/de)**2)
pl.figure(figsize=(14, 8), dpi=1000)
pl.plot(w,MH)
pl.show()
print 'w0 = ', 1/(R*C)
print 'f0 = ', 1/(2*np.pi*R*C)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# w0 =  100.0
# f0 =  15.9154943092
